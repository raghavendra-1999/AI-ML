# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("raghavendra.jpg")
print(img.shape)
# Out:
# (2151, 1280, 3)

# %%
## 2151-->height
## 1280-->width
## 3 ---->channels

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
## croping/slicing
plt.imshow(img[:,:1000,:])

# %%
plt.imshow(img[:1250,:1000,:])
